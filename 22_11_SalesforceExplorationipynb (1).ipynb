# %% [markdown]
# ##Preprocessing

# %%
#@title


# %%capture
! pip install pandas
import pandas as pd
import numpy as np

# %%
#@title


# %%capture
from ipywidgets import interact, Dropdown
from IPython.html import widgets
from IPython.display import display
! pip install panel 
import panel as pn
pn.extension()

# %%
#@title

from sklearn.preprocessing import LabelEncoder

# %%
#@title

ICALec = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/ICALec.csv', error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-a80ef6598765> in <module>()
#       1 #@title
#       2
# ----> 3 ICALec = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/ICALec.csv', error_bad_lines=False)
#
# ...

# %%
#@title

allc = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/SalesForceColumnDets.csv', error_bad_lines=False, usecols = ['table_name', 'schema_name', 'column_name', 'data_type', 'null?', 'default', 'kind', 'expression', 'comment', 'database_name',  'autoincrement']  ) 

tc = allc[allc.schema_name.isin(['TEST', 'TEST_STAGE'])] 

test = allc[allc.schema_name.isin(['TEST'])] 

test['DataType'] = test.data_type.str[9:13]
test[['table_name', 'schema_name', 'column_name', 'data_type', 'DataType']]

# %%
#@title


joined=pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/joined.csv',error_bad_lines=False)
joinedo = joined.select_dtypes(include = 'object')
joinedn = joined.select_dtypes(include = 'number')

# %%
#@title


tabUrl = ['https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/Account.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITYLINEITEM.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/USER.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITY.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITYLINEITEM.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/CODAINVOICE.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTE__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRODUCT2.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_PROGRAMME__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_MODULE__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/LA1_CODE__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROGRAMME__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_QUALIFICATION__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROFIT_CENTRE__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MERCIAREPORT.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MODULE__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/QUALIFICATION__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRICEBOOKENTRY.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/RECORDTYPE.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT_ASSIGNMENT__C.csv','https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/DATEDCONVERSIONRATE.csv']
allTabLis = ['ACCOUNT','CONTACT','USER','OPPORTUNITY','OPPORTUNITYLINEITEM','C2G__CODAINVOICE__C','C2G__CODACREDITNOTE__C','PRODUCT2','C2G__CODAINVOICELINEITEM__C','EVENT__C','C2G__CODACREDITNOTELINEITEM__C','STUDENT_PROGRAMME__C','STUDENT_MODULE__C','LA1_CODE__C','PROGRAMME__C','STUDENT_QUALIFICATION__C','PROFIT_CENTRE__C','MERCIAREPORT','MODULE__C','QUALIFICATION__C','PRICEBOOKENTRY','RECORDTYPE','EVENT_ASSIGNMENT__C','DATEDCONVERSIONRATE']

# %%
#@title


urlli =[] 
for i in tabUrl[0:len(tabUrl)]:
  x = pd.read_csv(i)
  urlli.append(x)

# %%
#@title

everydf = pd.concat(urlli)

# %%
#@title


allTabLisA = allTabLis[:4] 
allTabLisB = allTabLis[4:8]
allTabLisC = allTabLis[8:12]
allTabLisD = allTabLis[12:16]
allTabLisE = allTabLis[16:20]
allTabLisF = allTabLis[20:]

# %%
#@title


tableBoxA = pn.widgets.MultiSelect(name = 'Tables to read only Box 1:',
    options = allTabLisA
    ,value= allTabLisA

, size=4)  

tableBoxB = pn.widgets.MultiSelect(name = 'Tables to read only Box 2:',
    options = allTabLisB
    ,value= allTabLisB
, size=4)  

tableBoxC = pn.widgets.MultiSelect(name = 'Tables to read only Box 3:',
    options = allTabLisC
    ,value= allTabLisC

, size=4)  

tableBoxD = pn.widgets.MultiSelect(name = 'Tables to read only Box 4:',
    options = allTabLisD
    ,value= allTabLisD

, size=4)  

tableBoxE = pn.widgets.MultiSelect(name = 'Tables to read only Box 5:',
    options = allTabLisE
    ,value= allTabLisE

, size=4)  



comboTableBoxA = pn.widgets.MultiSelect(name = 'Tables to read & combine box 1:',
    options = allTabLisA
    ,value=['CONTACT']
, size=4)  

comboTableBoxB = pn.widgets.MultiSelect(name = 'Tables to read & combine box 2:',
    options = allTabLisB
, size=4)  

comboTableBoxC = pn.widgets.MultiSelect(name = 'Tables to read & combine box 3:',
    options = allTabLisC

, size=4)  

comboTableBoxD = pn.widgets.MultiSelect(name = 'Tables to read & combine box 4:',
    options = allTabLisD

, size=4)  

comboTableBoxE = pn.widgets.MultiSelect(name = 'Tables to read & combine box 5:',
    options = allTabLisE
, size=4)  


AllUrlbutton = pn.widgets.Button(name='Read All Test Salesforce Tables in one Dataframe', button_type='primary')


box1 = pn.WidgetBox('###    Select any number from anyone of the salesforce test tables to call them and read into INDIVIDUAL pandas dataframes','By default all read only tables are selected, left click to read just one in a box, hold control and left click to read in many',
                   pn.Row( tableBoxA,  tableBoxB, tableBoxC,  ) ,
            #       pn.Column('# Column', tableBoxA,  tableBoxB, background='WhiteSmoke') ,
                  pn.Row(  tableBoxD, tableBoxE, background='WhiteSmoke') , 
                    )

box2 = pn.WidgetBox( '###    Select any number from anyone of the salesforce test tables to call and read into one COMBINED pandas dataframe', 'THERE IS NO NEED TO SELECT ALL OF THEM! The button at the bottom will do that with a single press :)', 
 'By default only the Contact table within the Combo tables is selected',
                #   'press the all tables button at the botom to read in and combine all dataframes ',
        pn.Row( comboTableBoxA,  comboTableBoxB, comboTableBoxC, comboTableBoxD, comboTableBoxE), AllUrlbutton)


#display(pn.Row(WilmBox, clientBox, TypeBox, OppBox, weekToComplete))

# %% [markdown]
# ##Select Tables to Load / Read

# %%
#@title

display(pn.Row(box1, box2))

# %%
#@title
if (AllUrlbutton.clicks == 0):
  x = 'Button has not been pressed, we will not read all Salesforce tables into a single dataframe'.format((AllUrlbutton.clicks))
  y= False
elif (AllUrlbutton.clicks % 2 == 0):
  x = 'Button has been pressed {} times, as this is an even number, we will not read all Salesforce tables into one dataframe'.format((AllUrlbutton.clicks))
  y= True

else:
  x = 'Button has been pressed {} times, as this is an odd mumber, all Salesforce tables be read into one dataframe called everydf'.format((AllUrlbutton.clicks))
  y= False
x

# %% [markdown]
# ### Loading Selected Tables

# %%
#@title

allcomboTableBoxVal = comboTableBoxA.value + comboTableBoxB.value + comboTableBoxC.value + comboTableBoxD.value + comboTableBoxE.value

# %%
#@title

alltableBoxVal = tableBoxA.value + tableBoxB.value + tableBoxC.value + tableBoxD.value + tableBoxE.value

# %%
#@title

alltableBoxVal = [x for x in alltableBoxVal if x not in allcomboTableBoxVal]

# %%
#@title

dflist = [] 
if 'ACCOUNT' in allcomboTableBoxVal:  
    ACCOUNT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/Account.csv', error_bad_lines=False)    
    dflist.append( ACCOUNT )
if 'CONTACT' in allcomboTableBoxVal:  
    CONTACT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False) 
    dflist.append( CONTACT )
if 'USER' in allcomboTableBoxVal:  
    USER = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/USER.csv', error_bad_lines=False)    
    dflist.append( USER )
if 'OPPORTUNITY' in allcomboTableBoxVal:  
    OPPORTUNITY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITY.csv', error_bad_lines=False)    
    dflist.append( OPPORTUNITY )
if 'OPPORTUNITYLINEITEM' in allcomboTableBoxVal:  
    OPPORTUNITYLINEITEM = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITYLINEITEM.csv', error_bad_lines=False)    
    dflist.append( OPPORTUNITYLINEITEM )
if 'C2G__CODAINVOICE__C' in allcomboTableBoxVal:  
    C2G__CODAINVOICE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    dflist.append( C2G__CODAINVOICE__C )
if 'C2G__CODACREDITNOTE__C' in allcomboTableBoxVal:  
    C2G__CODACREDITNOTE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTE__C.csv', error_bad_lines=False)    
    dflist.append( C2G__CODACREDITNOTE__C )
if 'PRODUCT2' in allcomboTableBoxVal:  
    PRODUCT2 = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRODUCT2.csv', error_bad_lines=False)    
    dflist.append( PRODUCT2 )
if 'C2G__CODAINVOICELINEITEM__C' in allcomboTableBoxVal:  
    C2G__CODAINVOICELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    dflist.append( C2G__CODAINVOICELINEITEM__C )
if 'EVENT__C' in allcomboTableBoxVal:  
    EVENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT__C.csv', error_bad_lines=False)    
    dflist.append( EVENT__C )
if 'C2G__CODACREDITNOTELINEITEM__C' in allcomboTableBoxVal:  
    C2G__CODACREDITNOTELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False)    
    dflist.append( C2G__CODACREDITNOTELINEITEM__C )
if 'STUDENT_PROGRAMME__C' in allcomboTableBoxVal:  
    STUDENT_PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_PROGRAMME__C.csv', error_bad_lines=False)    
    dflist.append( STUDENT_PROGRAMME__C )
if 'STUDENT_MODULE__C' in allcomboTableBoxVal:  
    STUDENT_MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_MODULE__C.csv', error_bad_lines=False)    
    dflist.append( STUDENT_MODULE__C )
if 'LA1_CODE__C' in allcomboTableBoxVal:  
    LA1_CODE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/LA1_CODE__C.csv', error_bad_lines=False)    
    dflist.append( LA1_CODE__C )
if 'PROGRAMME__C' in allcomboTableBoxVal:  
    PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROGRAMME__C.csv', error_bad_lines=False)    
    dflist.append( PROGRAMME__C )
if 'STUDENT_QUALIFICATION__C' in allcomboTableBoxVal:  
    STUDENT_QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_QUALIFICATION__C.csv', error_bad_lines=False)    
    dflist.append( STUDENT_QUALIFICATION__C )
if 'PROFIT_CENTRE__C' in allcomboTableBoxVal:  
    PROFIT_CENTRE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROFIT_CENTRE__C.csv', error_bad_lines=False)    
    dflist.append( PROFIT_CENTRE__C )
if 'MERCIAREPORT' in allcomboTableBoxVal:  
    MERCIAREPORT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MERCIAREPORT.csv', error_bad_lines=False)    
    dflist.append( MERCIAREPORT )
if 'MODULE__C' in allcomboTableBoxVal:  
    MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MODULE__C.csv', error_bad_lines=False)    
    dflist.append( MODULE__C )
if 'QUALIFICATION__C' in allcomboTableBoxVal:  
    QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/QUALIFICATION__C.csv', error_bad_lines=False)    
    dflist.append( QUALIFICATION__C )
if 'PRICEBOOKENTRY' in allcomboTableBoxVal:  
    PRICEBOOKENTRY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRICEBOOKENTRY.csv', error_bad_lines=False)    
    dflist.append( PRICEBOOKENTRY )
if 'RECORDTYPE' in allcomboTableBoxVal:  
    RECORDTYPE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/RECORDTYPE.csv', error_bad_lines=False)  
    dflist.append( RECORDTYPE )
if 'EVENT_ASSIGNMENT__C' in allcomboTableBoxVal:  
    EVENT_ASSIGNMENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT_ASSIGNMENT__C.csv', error_bad_lines=False)    
    dflist.append( EVENT_ASSIGNMENT__C )
if 'DATEDCONVERSIONRATE' in allcomboTableBoxVal:  
    DATEDCONVERSIONRATE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/DATEDCONVERSIONRATE.csv', error_bad_lines=False)    
    dflist.append( DATEDCONVERSIONRATE )
if y == True:
    everydf = pd.concat(urlli)

# %%
#@title

if 'ACCOUNT' in alltableBoxVal:  
    ACCOUNT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/Account.csv', error_bad_lines=False)    
    #dflist.append( ACCOUNT )
if 'CONTACT' in alltableBoxVal:  
    CONTACT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False) 
    #dflist.append( CONTACT )
if 'USER' in alltableBoxVal:  
    USER = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/USER.csv', error_bad_lines=False)    
    #dflist.append( USER )
if 'OPPORTUNITY' in alltableBoxVal:  
    OPPORTUNITY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITY.csv', error_bad_lines=False)    
    #dflist.append( OPPORTUNITY )
if 'OPPORTUNITYLINEITEM' in alltableBoxVal:  
    OPPORTUNITYLINEITEM = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITYLINEITEM.csv', error_bad_lines=False)    
    #dflist.append( OPPORTUNITYLINEITEM )
if 'C2G__CODAINVOICE__C' in alltableBoxVal:  
    C2G__CODAINVOICE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    #dflist.append( C2G__CODAINVOICE__C )
if 'C2G__CODACREDITNOTE__C' in alltableBoxVal:  
    C2G__CODACREDITNOTE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTE__C.csv', error_bad_lines=False)    
    #dflist.append( C2G__CODACREDITNOTE__C )
if 'PRODUCT2' in alltableBoxVal:  
    PRODUCT2 = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRODUCT2.csv', error_bad_lines=False)    
    #dflist.append( PRODUCT2 )
if 'C2G__CODAINVOICELINEITEM__C' in alltableBoxVal:  
    C2G__CODAINVOICELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    #dflist.append( C2G__CODAINVOICELINEITEM__C )
if 'EVENT__C' in alltableBoxVal:  
    EVENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT__C.csv', error_bad_lines=False)    
    #dflist.append( EVENT__C )
if 'C2G__CODACREDITNOTELINEITEM__C' in alltableBoxVal:  
    C2G__CODACREDITNOTELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False)    
    #dflist.append( C2G__CODACREDITNOTELINEITEM__C )
if 'STUDENT_PROGRAMME__C' in alltableBoxVal:  
    STUDENT_PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_PROGRAMME__C.csv', error_bad_lines=False)    
    #dflist.append( STUDENT_PROGRAMME__C )
if 'STUDENT_MODULE__C' in alltableBoxVal:  
    STUDENT_MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_MODULE__C.csv', error_bad_lines=False)    
    #dflist.append( STUDENT_MODULE__C )
if 'LA1_CODE__C' in alltableBoxVal:  
    LA1_CODE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/LA1_CODE__C.csv', error_bad_lines=False)    
    #dflist.append( LA1_CODE__C )
if 'PROGRAMME__C' in alltableBoxVal:  
    PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROGRAMME__C.csv', error_bad_lines=False)    
    #dflist.append( PROGRAMME__C )
if 'STUDENT_QUALIFICATION__C' in alltableBoxVal:  
    STUDENT_QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_QUALIFICATION__C.csv', error_bad_lines=False)    
    #dflist.append( STUDENT_QUALIFICATION__C )
if 'PROFIT_CENTRE__C' in alltableBoxVal:  
    PROFIT_CENTRE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROFIT_CENTRE__C.csv', error_bad_lines=False)    
    #dflist.append( PROFIT_CENTRE__C )
if 'MERCIAREPORT' in alltableBoxVal:  
    MERCIAREPORT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MERCIAREPORT.csv', error_bad_lines=False)    
    #dflist.append( MERCIAREPORT )
if 'MODULE__C' in alltableBoxVal:  
    MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MODULE__C.csv', error_bad_lines=False)    
    #dflist.append( MODULE__C )
if 'QUALIFICATION__C' in alltableBoxVal:  
    QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/QUALIFICATION__C.csv', error_bad_lines=False)    
    #dflist.append( QUALIFICATION__C )
if 'PRICEBOOKENTRY' in alltableBoxVal:  
    PRICEBOOKENTRY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRICEBOOKENTRY.csv', error_bad_lines=False)    
    #dflist.append( PRICEBOOKENTRY )
if 'RECORDTYPE' in alltableBoxVal:  
    RECORDTYPE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/RECORDTYPE.csv', error_bad_lines=False)    
    #dflist.append( RECORDTYPE )
if 'EVENT_ASSIGNMENT__C' in alltableBoxVal:  
    EVENT_ASSIGNMENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT_ASSIGNMENT__C.csv', error_bad_lines=False)    
    #dflist.append( EVENT_ASSIGNMENT__C )
if 'DATEDCONVERSIONRATE' in alltableBoxVal:  
    DATEDCONVERSIONRATE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/DATEDCONVERSIONRATE.csv', error_bad_lines=False)    
    #dflist.append( DATEDCONVERSIONRATE )

# %%
#@title

if dflist == []:
  'None of the Combo tables are selected, so there are no table to merge'
else:
  allselecteddfs = pd.concat(dflist)

# %% [markdown]
# ## Function to look up the details of salesforce columns, whose names are contained in the input string(s)
#
# **Determine table to search:**
# Please choose a table to look up, from the 'Tables to Search Box'. On the left, you will see the box containing all the Salesforce tables that have not been selected. The box on the right contains the Salesforce tables that have been selected and will be searched. CONTACT and EVENT__C tables are selected and will be searched by default.
# Left click on a table name to select from either box, hold control and left click to select in many.
# Use the arrows to move selected tables between the left 'not to be searched' and the right 'to be searched' box.
#
# **Type to find column names to search**
# To filter columns by their name, please type the beggining of column name(s) you would like to lookup in any number of the four, "Column name to lookup autofill". You can also type any text to search for Column names containing this input with the four right most, "Part of, or entire column name to lookup, freetext" boxes.
#
#
# **Determine number of rows returned:**
# To view the top and bottom 5 rows only, set the viewAllRows argument to 'no'
# To view all rows of the column details result again, set the viewAllRows argument to 'yes'
#
# **Filter columns by data type:**
# Please choose a selection from the 'Filter Column Details By Their Data Type' box

# %%
#@title
allTabLis.sort()

TableColumnDetsBox = pn.widgets.CrossSelector(name = 'Tables to search:',
    options = allTabLis, 
    value = [
 'CONTACT',
 'EVENT__C'], size = 24)


box = pn.WidgetBox(
    pn.Row(TableColumnDetsBox
) ,  height = 450
)
box

# %%
#@title
lst = []
def ColDetsForColString(table):
  if isinstance(table, list):
      for i in table:
        lst.append(test[test.table_name == str(i)][['table_name','schema_name','column_name','data_type','null?']])
        ColDetsForColString.table= pd.concat(lst)
  elif table is not tc or test: 
        ColDetsForColString.table = test[test.table_name == table]

ColDetsForColString(TableColumnDetsBox.value)

# %%
#@title


autocomplete7 = pn.widgets.AutocompleteInput(
     name='Column name to lookup autofill 1:', # value= (ColDetsForColString.table.column_name.tolist()[ - len( ColDetsForColString.table.column_name.tolist() )] )     ,
     options =ColDetsForColString.table.column_name.tolist()       , case_sensitive  = False   ) 

autocomplete1 = pn.widgets.AutocompleteInput(
     name='Column name to lookup autofill 2:', #value= (ColDetsForColString.table.column_name.tolist()[1 - len( ColDetsForColString.table.column_name.tolist() )] )     ,
     options =ColDetsForColString.table.column_name.tolist()       , case_sensitive  = False   ) 


autocomplete2 = pn.widgets.AutocompleteInput(
     name='Column name to lookup autofill 3:', #value= (ColDetsForColString.table.column_name.tolist()[2 - len( ColDetsForColString.table.column_name.tolist() )] )     ,
     options =ColDetsForColString.table.column_name.tolist()      , case_sensitive  = False   ) 


autocomplete3 = pn.widgets.AutocompleteInput(
     name='Column name to lookup autofill 4:', #value= (ColDetsForColString.table.column_name.tolist()[3 - len( ColDetsForColString.table.column_name.tolist() )] )     ,
     options =ColDetsForColString.table.column_name.tolist()   , case_sensitive  = False   ) 


autocomplete4 = pn.widgets.TextAreaInput(
     name='Part of, or entire column name to lookup, freetext A:', #value= (ColDetsForColString.table.column_name.tolist()[4 - len( ColDetsForColString.table.column_name.tolist() )] )     ,
  )#   options =ColDetsForColString.table.column_name.tolist()     , case_sensitive  = False   ) 


autocomplete5 = pn.widgets.TextAreaInput(
     name='Part of, or entire column name to lookup, freetext B:', #value= (ColDetsForColString.table.column_name.tolist()[5 - len( ColDetsForColString.table.column_name.tolist() )] )     ,
 )#    options =ColDetsForColString.table.column_name.tolist()      , case_sensitive  = False   ) 


autocomplete6 = pn.widgets.TextAreaInput(
     name='Part of, or entire column name to lookup, freetext C:', #value= (ColDetsForColString.table.column_name.tolist()[6 - len( ColDetsForColString.table.column_name.tolist() )] )     
   #  options =ColDetsForColString.table.column_name.tolist()      , case_sensitive  = False   ) 
 
) 

autocomplete0 = pn.widgets.TextAreaInput(
     name='Part of, or entire column name to lookup, freetext D:', 
   #  options =ColDetsForColString.table.column_name.tolist(), case_sensitive = False      )                
)
AllRowsColName = pn.widgets.CheckBoxGroup(value=['Show all rows'],
    options=['Show all rows'], width = 110)


css = '''
.bk.panel-widget-box {
  background: #f0f0f0;
  border-radius: 5px;
  border: 1px black solid;
}
'''

pn.extension(raw_css=[css])

box = pn.WidgetBox(
    pn.Row(
    pn.Column(AllRowsColName, autocomplete7, autocomplete1, autocomplete2, autocomplete3, background='White'  ) , 
    pn.Column(autocomplete4, autocomplete5, autocomplete6, autocomplete0,  css_classes=['panel-widget-box']  )
) ,  height = 480
)




box

# %%
#@title


l = []
l2 = []
colcontentlst = list(filter(None,[autocomplete0.value,autocomplete1.value,autocomplete2.value,autocomplete3.value,autocomplete4.value,autocomplete5.value,autocomplete6.value,autocomplete7.value]  ))

def colLookUp(colNameContent, viewAllRows = 'yes', table= test):
      if isinstance(table, list):
          for i in table:
            l.append(test[test.table_name == str(i)][['table_name','schema_name','column_name','DataType','null?']])
            table= pd.concat(l)
      elif table is not tc or test: 
            table = test[test.table_name == table]
      
      if isinstance(colNameContent, list):
          if colNameContent == []:
            print('No column contents to search. Please Choose a value to find in the column lookup boxes above!')
          for i in range(0, len(colNameContent)):
              l2.append(table[table['column_name'].str.contains(colNameContent[i])][['column_name', 'schema_name', 'table_name',   'DataType', 'null?']] )
          coltab = pd.concat(l2)
          display(coltab)
      else: 
          containingColumn = table[table['column_name'].str.contains(colNameContent)] 
          colLookUp.cc =  containingColumn[['column_name', 'schema_name', 'table_name',   'DataType', 'null?']]
          display( containingColumn[['column_name', 'schema_name', 'table_name',   'DataType', 'null?']] )

      if viewAllRows == ['Show all rows']:
        pd.set_option('display.max_rows', None)
      else:
        pd.set_option('display.max_rows', 10)

colLookUp(colNameContent = colcontentlst,  viewAllRows = AllRowsColName.value,  table = alltableBoxVal)

# %% [markdown]
# ### Function to look up the details of all columns in a specified SalesForce Table/Tables
#
# **Determine table to search**
#
# Please choose a table to look up, from the 'Tables to Search Box', ACCOUNT, CONTACT, USER AND LAI_CODE__C are all are selected by default
#
# ---
#
# **Determine number of rows returned**
#
# To view the top and bottom 5 rows only, set the viewAllRows argument to 'no'
# To view all rows of the column details result again, set the viewAllRows argument to 'yes'
#
# ---
#
# **Determine data type to search**
#
# To view the data type, please choose a selection from the  'Filter Column Details By Their Data Type' box

# %%
#@title

alltableBoxVal = [x for x in alltableBoxVal if x not in allcomboTableBoxVal]

# %%
#@title


TableToSearchBox = pn.widgets.CrossSelector(name = 'Tables to search:',
    options = allTabLis, 
    value = ['ACCOUNT',
 'CONTACT',
 'USER', 'LA1_CODE__C'], size = 20)


dtypeBox = pn.widgets.CheckBoxGroup(name = 'Filter Column Details By Their Data Type:',
    options = ['TEXT', 'BOOLEAN', 'FIXED', 'REAL', 'All'],
    value = ['All']
)  


AllRows = pn.widgets.CheckBoxGroup(value=['Show all rows'],
    options=['Show all rows'], width = 110)

box = pn.WidgetBox(
    pn.Row(
    pn.Column(TableToSearchBox), 
    pn.Column('Column Data Type Filter:', dtypeBox, 'Size of Column Details Display:', AllRows, width=200)
) ,  height = 450
)
box

# %%
#@title

lis = [] 
dtypeBoxLi = []

def colintable(table, viewAllRows = 'yes', datatype='TEXT'):
    if isinstance(table, list):
        for i in table:
          lis.append(test[test.table_name == str(i)][['table_name','schema_name','column_name','DataType','null?']])
          colintable.cols = pd.concat(lis)
    else:
      colintable.cols = test[test.table_name == table][['table_name','schema_name','column_name','DataType','null?']]
    if viewAllRows == ['Show all rows']:
     pd.set_option('display.max_rows', None)
    else:
     pd.set_option('display.max_rows', 10)


    if datatype != []:
      if 'REAL' in datatype:
        colintable.colsR =   colintable.cols[  colintable.cols.data_type.str.contains('REAL')  ]
        dtypeBoxLi.append(colintable.colsR)


      if 'TEXT' in datatype:
        colintable.colsT =   colintable.cols[  colintable.cols.data_type.str.contains('TEXT')  ]
        dtypeBoxLi.append(colintable.colsT)

      if 'FIXED' in datatype:
        colintable.colsF = colintable.cols[  colintable.cols.data_type.str.contains('REAL')  ]
        dtypeBoxLi.append(colintable.colsF)

      if 'BOOLEAN' in datatype:
        colintable.colsB = colintable.cols[test[datatype]].str.contains('BOOLEAN')
        dtypeBoxLi.append(colintable.colsB)
      try:
        dtypeDF = pd.concat(dtypeBoxLi)
      except:
        pass
      if 'All' in datatype:
        dtypeDF = colintable.cols
      return dtypeDF
    else:
        print('No DataTypes Selected') 

    colintable.cols = colintable.cols[test[datatype] ]  #.str.contains(datatype)]



  
 
colintable(TableToSearchBox.value, viewAllRows = AllRows.value, datatype= dtypeBox.value)

# %% [markdown]
# ## Returns values matching with Salesforce
#
# #### Function that inputs a column and table of your choice, and that returns the columns with values contained within both the chosen column and chosen Salesforce table(s). The number of values that match in each column and the matching values themselves are also returned.

# %%
#@title


TableToSearchBox = pn.widgets.CrossSelector(name = 'Tables to Search:',
    options = allTabLis, 
    value = ['ACCOUNT',
 'CONTACT',
 'USER', 'LA1_CODE__C'], size = 24)


coltosearch = pn.widgets.CheckBoxGroup(name = 'Table to LookUp Column:',
    options = allTabLis,
    value = ['ACCOUNT']
)  


AllRows = pn.widgets.CheckBoxGroup(value=['Show all rows'],
    options=['Show all rows'], width = 110)

box = pn.WidgetBox(
    pn.Row(
    pn.Column('Tables To Search:',TableToSearchBox), 
    pn.Column('Table containing Column to Lookup:', coltosearch, width=200)
) ,  height = 503
)
box

# %%
#@title
lst = []
def ColDetsForColString(table):
  if isinstance(table, list):
      for i in table:
        lst.append(test[test.table_name == str(i)][['table_name','schema_name','column_name','data_type','null?']])
        ColDetsForColString.table= pd.concat(lst)
  elif table is not tc or test: 
        ColDetsForColString.table = test[test.table_name == table]

ColDetsForColString(TableColumnDetsBox.value)

# %%
#@title


autocomplete = pn.widgets.AutocompleteInput(
     name='Column name to lookup 1:', # value= (ColDetsForColString.table.column_name.tolist()[ - len( ColDetsForColString.table.column_name.tolist() )] )     ,
     options =ColDetsForColString.table.column_name.tolist()       , case_sensitive  = False   ) 



css = '''
.bk.panel-widget-box {
  background: #f0f0f0;
  border-radius: 5px;
  border: 1px black solid;
}
'''

pn.extension(raw_css=[css])

box = pn.WidgetBox(
    pn.Row(
    pn.Column(autocomplete, background='White'  )
) ,  height = 480
)




box

# %% [markdown]
# ## Selected Table Loading for  values matching function

# %%
#@title

dflist3 = [] 
if 'ACCOUNT' in TableToSearchBox.value:  
    ACCOUNT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/Account.csv', error_bad_lines=False)    
    dflist3.append( ACCOUNT )
if 'CONTACT' in TableToSearchBox.value:  
    CONTACT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False) 
    dflist3.append( CONTACT )
if 'USER' in TableToSearchBox.value:  
    USER = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/USER.csv', error_bad_lines=False)    
    dflist3.append( USER )
if 'OPPORTUNITY' in TableToSearchBox.value:  
    OPPORTUNITY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITY.csv', error_bad_lines=False)    
    dflist3.append( OPPORTUNITY )
if 'OPPORTUNITYLINEITEM' in TableToSearchBox.value:  
    OPPORTUNITYLINEITEM = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITYLINEITEM.csv', error_bad_lines=False)    
    dflist3.append( OPPORTUNITYLINEITEM )
if 'C2G__CODAINVOICE__C' in TableToSearchBox.value:  
    C2G__CODAINVOICE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    dflist3.append( C2G__CODAINVOICE__C )
if 'C2G__CODACREDITNOTE__C' in TableToSearchBox.value:  
    C2G__CODACREDITNOTE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTE__C.csv', error_bad_lines=False)    
    dflist3.append( C2G__CODACREDITNOTE__C )
if 'PRODUCT2' in TableToSearchBox.value:  
    PRODUCT2 = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRODUCT2.csv', error_bad_lines=False)    
    dflist3.append( PRODUCT2 )
if 'C2G__CODAINVOICELINEITEM__C' in TableToSearchBox.value:  
    C2G__CODAINVOICELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    dflist3.append( C2G__CODAINVOICELINEITEM__C )
if 'EVENT__C' in TableToSearchBox.value:  
    EVENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT__C.csv', error_bad_lines=False)    
    dflist3.append( EVENT__C )
if 'C2G__CODACREDITNOTELINEITEM__C' in TableToSearchBox.value:  
    C2G__CODACREDITNOTELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False)    
    dflist3.append( C2G__CODACREDITNOTELINEITEM__C )
if 'STUDENT_PROGRAMME__C' in TableToSearchBox.value:  
    STUDENT_PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_PROGRAMME__C.csv', error_bad_lines=False)    
    dflist3.append( STUDENT_PROGRAMME__C )
if 'STUDENT_MODULE__C' in TableToSearchBox.value:  
    STUDENT_MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_MODULE__C.csv', error_bad_lines=False)    
    dflist3.append( STUDENT_MODULE__C )
if 'LA1_CODE__C' in TableToSearchBox.value:  
    LA1_CODE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/LA1_CODE__C.csv', error_bad_lines=False)    
    dflist3.append( LA1_CODE__C )
if 'PROGRAMME__C' in TableToSearchBox.value:  
    PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROGRAMME__C.csv', error_bad_lines=False)    
    dflist3.append( PROGRAMME__C )
if 'STUDENT_QUALIFICATION__C' in TableToSearchBox.value:  
    STUDENT_QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_QUALIFICATION__C.csv', error_bad_lines=False)    
    dflist3.append( STUDENT_QUALIFICATION__C )
if 'PROFIT_CENTRE__C' in TableToSearchBox.value:  
    PROFIT_CENTRE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROFIT_CENTRE__C.csv', error_bad_lines=False)    
    dflist3.append( PROFIT_CENTRE__C )
if 'MERCIAREPORT' in TableToSearchBox.value:  
    MERCIAREPORT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MERCIAREPORT.csv', error_bad_lines=False)    
    dflist3.append( MERCIAREPORT )
if 'MODULE__C' in TableToSearchBox.value:  
    MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MODULE__C.csv', error_bad_lines=False)    
    dflist3.append( MODULE__C )
if 'QUALIFICATION__C' in TableToSearchBox.value:  
    QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/QUALIFICATION__C.csv', error_bad_lines=False)    
    dflist3.append( QUALIFICATION__C )
if 'PRICEBOOKENTRY' in TableToSearchBox.value:  
    PRICEBOOKENTRY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRICEBOOKENTRY.csv', error_bad_lines=False)    
    dflist3.append( PRICEBOOKENTRY )
if 'RECORDTYPE' in TableToSearchBox.value:  
    RECORDTYPE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/RECORDTYPE.csv', error_bad_lines=False)  
    dflist3.append( RECORDTYPE )
if 'EVENT_ASSIGNMENT__C' in TableToSearchBox.value:  
    EVENT_ASSIGNMENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT_ASSIGNMENT__C.csv', error_bad_lines=False)    
    dflist3.append( EVENT_ASSIGNMENT__C )
if 'DATEDCONVERSIONRATE' in TableToSearchBox.value:  
    DATEDCONVERSIONRATE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/DATEDCONVERSIONRATE.csv', error_bad_lines=False)    
    dflist3.append( DATEDCONVERSIONRATE )




ToSearchTable =     pd.concat(dflist3)

# %%
#@title

if 'ACCOUNT' in coltosearch.value:  
    ACCOUNT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/Account.csv', error_bad_lines=False)    
    coltofindtab = ACCOUNT 
if 'CONTACT' in coltosearch.value:  
    CONTACT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False) 
    coltofindtab = CONTACT 
if 'USER' in coltosearch.value:  
    USER = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/USER.csv', error_bad_lines=False)    
    coltofindtab = USER 
if 'OPPORTUNITY' in coltosearch.value:  
    OPPORTUNITY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITY.csv', error_bad_lines=False)    
    coltofindtab = OPPORTUNITY 
if 'OPPORTUNITYLINEITEM' in coltosearch.value:  
    OPPORTUNITYLINEITEM = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/OPPORTUNITYLINEITEM.csv', error_bad_lines=False)    
    coltofindtab = OPPORTUNITYLINEITEM 
if 'C2G__CODAINVOICE__C' in coltosearch.value:  
    C2G__CODAINVOICE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    coltofindtab = C2G__CODAINVOICE__C 
if 'C2G__CODACREDITNOTE__C' in coltosearch.value:  
    C2G__CODACREDITNOTE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTE__C.csv', error_bad_lines=False)    
    coltofindtab = C2G__CODACREDITNOTE__C 
if 'PRODUCT2' in coltosearch.value:  
    PRODUCT2 = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRODUCT2.csv', error_bad_lines=False)    
    coltofindtab = PRODUCT2 
if 'C2G__CODAINVOICELINEITEM__C' in coltosearch.value:  
    C2G__CODAINVOICELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODAINVOICELINEITEM__C.csv', error_bad_lines=False)    
    coltofindtab = C2G__CODAINVOICELINEITEM__C 
if 'EVENT__C' in coltosearch.value:  
    EVENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT__C.csv', error_bad_lines=False)    
    coltofindtab = EVENT__C 
if 'C2G__CODACREDITNOTELINEITEM__C' in coltosearch.value:  
    C2G__CODACREDITNOTELINEITEM__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/C2G__CODACREDITNOTELINEITEM__C.csv', error_bad_lines=False)    
    coltofindtab = C2G__CODACREDITNOTELINEITEM__C 
if 'STUDENT_PROGRAMME__C' in coltosearch.value:  
    STUDENT_PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_PROGRAMME__C.csv', error_bad_lines=False)    
    coltofindtab = STUDENT_PROGRAMME__C 
if 'STUDENT_MODULE__C' in coltosearch.value:  
    STUDENT_MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_MODULE__C.csv', error_bad_lines=False)    
    coltofindtab = STUDENT_MODULE__C 
if 'LA1_CODE__C' in coltosearch.value:  
    LA1_CODE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/LA1_CODE__C.csv', error_bad_lines=False)    
    coltofindtab = LA1_CODE__C 
if 'PROGRAMME__C' in coltosearch.value:  
    PROGRAMME__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROGRAMME__C.csv', error_bad_lines=False)    
    coltofindtab = PROGRAMME__C 
if 'STUDENT_QUALIFICATION__C' in coltosearch.value:  
    STUDENT_QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/STUDENT_QUALIFICATION__C.csv', error_bad_lines=False)    
    coltofindtab = STUDENT_QUALIFICATION__C 
if 'PROFIT_CENTRE__C' in coltosearch.value:  
    PROFIT_CENTRE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PROFIT_CENTRE__C.csv', error_bad_lines=False)    
    coltofindtab = PROFIT_CENTRE__C 
if 'MERCIAREPORT' in coltosearch.value:  
    MERCIAREPORT = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MERCIAREPORT.csv', error_bad_lines=False)    
    coltofindtab = MERCIAREPORT 
if 'MODULE__C' in coltosearch.value:  
    MODULE__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/MODULE__C.csv', error_bad_lines=False)    
    coltofindtab = MODULE__C 
if 'QUALIFICATION__C' in coltosearch.value:  
    QUALIFICATION__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/QUALIFICATION__C.csv', error_bad_lines=False)    
    coltofindtab = QUALIFICATION__C 
if 'PRICEBOOKENTRY' in coltosearch.value:  
    PRICEBOOKENTRY = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/PRICEBOOKENTRY.csv', error_bad_lines=False)    
    coltofindtab = PRICEBOOKENTRY 
if 'RECORDTYPE' in coltosearch.value:  
    RECORDTYPE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/RECORDTYPE.csv', error_bad_lines=False)    
    coltofindtab = RECORDTYPE 
if 'EVENT_ASSIGNMENT__C' in coltosearch.value:  
    EVENT_ASSIGNMENT__C = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/EVENT_ASSIGNMENT__C.csv', error_bad_lines=False)    
    coltofindtab = EVENT_ASSIGNMENT__C 
if 'DATEDCONVERSIONRATE' in coltosearch.value:  
    DATEDCONVERSIONRATE = pd.read_csv(r'https://raw.githubusercontent.com/DataTeamSam/Salesforce/main/DATEDCONVERSIONRATE.csv', error_bad_lines=False)    
    coltofindtab = DATEDCONVERSIONRATE

# %%
#@title

 
 
li = []
def itera(targetdf, targetcol, wholedf):

    if isinstance(wholedf, list):
        for i in wholedf:
            wholedf = i.replace("'", " ")
    if isinstance(targetcol, list):
        for i in targetcol:
            litarg.append(wholedf.apply(lambda x: x[x.isin(targetdf[i].values.flatten())], axis=0).dropna(how='all', axis =1))
            a = pd.concat(litarg)

        # for i in range(0, len(colNameContent)):
        #       l2.append(table[table['column_name'].str.contains(colNameContent[i])][['column_name', 'schema_name', 'table_name',   'data_type', 'null?']] )
        #   coltab = pd.concat(l2)
        #   display(coltab)
    else:
      if(targetdf[targetcol].dtype == np.number):
        wholedf = wholedf.select_dtypes(include = 'number')
      # elif (targetdf[targetcol].dtype == np.object): 
      #     wholedf = wholedf.select_dtypes(include = 'object')

      wholedf= wholedf.replace(dict.fromkeys([True,False], np.NaN))

      a = wholedf.apply(lambda x: x[x.isin(targetdf[targetcol].values.flatten())], axis=0).dropna(how='all', axis =1)
      for i in range(0, a.shape[1]):
          li.append(a.iloc[:,i].dropna(how='all', axis =0)) 

    df = pd.DataFrame(li).T
    if df.empty == True:
      return 'No matching columns'

    dfs = pd.DataFrame(df.isnull().sum())#
    dfs.columns = ['Number of Matches']
    dfs = df.shape[0] - dfs
    
    if isinstance(targetcol, list) == False:
      if(targetdf[targetcol].dtype == np.number):
          print('Difference between target column mean and columns in input wholedf mean:')

          x = targetdf[targetcol].mean() - df.mean() 
          x = x.sort_values() 
          z = pd.DataFrame(x)
          z.columns = ['Target Col And Wholedf Col Diff, ordered by diff']
          display(z) 
          meanseries = pd.Series(targetdf[targetcol].mean() - df.mean())
          dfs['Target Col And Wholedf Col Diff'] = meanseries
          dfs.loc[dfs['Target Col And Wholedf Col Diff'] == 0, 'Target Col And Wholedf Col Diff'] = None
            #df['Target'] = df.mean() - targetdf[targetcol].mean() 
      
    
    print('Number of matches in each coloumn with a match in the set whole dataframe target column:')
    display(dfs.sort_values(by = 'Number of Matches', ascending = False))

    

    print('Values of all columns that contain a matching value with the input target col ')
    display(pd.DataFrame(li))
    print(pd.DataFrame(li).index[0]) 
    itera.enddf = pd.DataFrame(li)
 

    y =  pd.DataFrame(li).reset_index() 

    print('Table, schema and data type of matched columns:')
    # for i in range(0, y.shape[0] ):
    #   display(test [test.column_name == y['index'][0] ][['column_name','table_name','schema_name','DataType','null?']] ) 
    display(test [test.column_name == y['index'][0] ][['column_name','table_name','schema_name','DataType','null?']] ) 
    
itera(targetdf = coltofindtab.iloc[0:50], targetcol = autocomplete.value, wholedf =  ToSearchTable.iloc[0:500] )
